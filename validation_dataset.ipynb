# %%
import pandas as pd

# %%
a=pd.read_csv("./true_target.txt",header=None)
b=pd.read_csv("./error_input.txt",header=None)
c=pd.concat([a,b],axis=1)
print(c)
# Out:
#                                                        0  \
# 0      C O C ( = O ) c 1 c c ( C C C c 2 c c 3 c ( = ...
# 1      C O C ( = O ) c 1 c c ( C C C c 2 c c 3 c ( = ...
# 2      C O C ( = O ) c 1 c c ( C C C c 2 c c 3 c ( = ...
# 3      C C 1 ( C ) O B ( B 2 O C ( C ) ( C ) C ( C ) ...
# 4      C C 1 ( C ) O B ( B 2 O C ( C ) ( C ) C ( C ) ...
# 5      C C 1 ( C ) O B ( B 2 O C ( C ) ( C ) C ( C ) ...
# 6      C C 1 ( C ) O B ( B 2 O C ( C ) ( C ) C ( C ) ...
# 7      C C ( C ) ( C ) O C ( = O ) N C C ( = O ) C C ...
# 8      F c 1 c c 2 c ( C l ) n c n c 2 c n 1 . N C 1 ...
# 9      C O c 1 c c c ( S ( = O ) ( = O ) C l ) c ( [ ...
# 10     C O c 1 c c c ( S ( = O ) ( = O ) C l ) c ( [ ...
# 11     C [ C @ H ] ( N C ( = O ) c 1 c c ( C l ) c n ...
# 12     C [ C @ H ] ( N C ( = O ) c 1 c c ( C l ) c n ...
# 13     C l C c 1 c c c c c 1 . c 1 c c c 2 [ n H ] c ...
# 14     C l C c 1 c c c c c 1 . c 1 c c c 2 [ n H ] c ...
# ...

# %%
c=c.sample(frac=1)

# %%
c.iloc[:,0].to_csv(r'true_target_shuffle.txt',header=None,index=None)
c.iloc[:,1].to_csv(r'error_input_shuffle.txt',header=None,index=None)
